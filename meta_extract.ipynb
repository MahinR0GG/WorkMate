# %%
import os
import json
from datetime import datetime

# %%
def extract_file_metadata(file_path = "Leave-Policy.docx"):
    """
    Extract basic technical metadata from a document
    """

    metadata = {}

    # File path details
    metadata["filename"] = os.path.basename(file_path)
    metadata["file_location"] = os.path.dirname(os.path.abspath(file_path))
    metadata["file_type"] = os.path.splitext(file_path)[1].lower()

    # Last modified date
    last_modified_timestamp = os.path.getmtime(file_path)
    metadata["last_modified_date"] = datetime.fromtimestamp(
        last_modified_timestamp
    ).strftime("%Y-%m-%d %H:%M:%S")

    return metadata


def save_metadata_to_json(metadata, output_file="metadata.json"):
    """
    Save metadata dictionary to JSON file
    """
    with open(output_file, "w", encoding="utf-8") as json_file:
        json.dump(metadata, json_file, indent=4)


if __name__ == "__main__":
    # Path to FAQ document (DOCX or PDF)
    file_path = "Leave-Policy.docx"   # change path as needed

    metadata = extract_file_metadata(file_path)

    save_metadata_to_json(metadata)

    print("Metadata extracted successfully:")
    print(json.dumps(metadata, indent=4))
# Out:
# Metadata extracted successfully:
# {
#     "filename": "Leave-Policy.docx",
#     "file_location": "c:\\Users\\Cymonic\\Desktop\\Cymonic\\HR_BOT\\WorkMate",
#     "file_type": ".docx",
#     "last_modified_date": "2026-01-30 10:48:59"
# }

# %%
import os
import json
from datetime import datetime

def extract_file_metadata(file_path):
    metadata = {}
    metadata["filename"] = os.path.basename(file_path)
    metadata["file_location"] = os.path.dirname(os.path.abspath(file_path))
    metadata["file_type"] = os.path.splitext(file_path)[1].lower()
    last_modified_timestamp = os.path.getmtime(file_path)
    metadata["last_modified_date"] = datetime.fromtimestamp(
        last_modified_timestamp
    ).strftime("%Y-%m-%d %H:%M:%S")
    return metadata

def save_metadata_to_json(metadata_list, output_file="metadata1.json"):
    with open(output_file, "w", encoding="utf-8") as json_file:
        json.dump(metadata_list, json_file, indent=4)

if __name__ == "__main__":
    folder_path = r"C:\Users\Cymonic\Desktop\Cymonic\HR_BOT\WorkMate"  # path to your folder containing all docs
    all_metadata = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path) and filename.lower().endswith(('.docx', '.pdf')):
            metadata = extract_file_metadata(file_path)
            all_metadata.append(metadata)

    save_metadata_to_json(all_metadata)
    print(f"Metadata extracted for {len(all_metadata)} files successfully!")
# Out:
# Metadata extracted for 4 files successfully!

# %%
import os
import json
from datetime import datetime

class DocumentMetadataExtractor:
    """
    Extracts technical metadata from FAQ documents (DOCX / PDF)
    """

    SUPPORTED_EXTENSIONS = (".docx", ".pdf")

    def __init__(self, folder_path, output_file="metadata12.json"):
        self.folder_path = folder_path
        self.output_file = output_file

    def extract_file_metadata(self, file_path):
        """
        Extract metadata for a single file
        """
        metadata = {
            "filename": os.path.basename(file_path),
            "file_location": os.path.dirname(os.path.abspath(file_path)),
            "file_type": os.path.splitext(file_path)[1].lower(),
            "last_modified_date": datetime.fromtimestamp(
                os.path.getmtime(file_path)
            ).strftime("%Y-%m-%d %H:%M:%S")
        }
        return metadata

    def process_documents(self):
        """
        Process all supported documents in the folder
        """
        all_metadata = []

        for filename in os.listdir(self.folder_path):
            file_path = os.path.join(self.folder_path, filename)

            if (
                os.path.isfile(file_path)
                and filename.lower().endswith(self.SUPPORTED_EXTENSIONS)
            ):
                metadata = self.extract_file_metadata(file_path)
                all_metadata.append(metadata)

        return all_metadata

    def save_to_json(self, metadata_list):
        """
        Save extracted metadata to JSON file
        """
        with open(self.output_file, "w", encoding="utf-8") as json_file:
            json.dump(metadata_list, json_file, indent=4)

    def run(self):
        """
        Execute full metadata extraction pipeline
        """
        metadata = self.process_documents()
        self.save_to_json(metadata)
        print(f"Metadata extracted for {len(metadata)} files successfully.")


# -------------------- Usage --------------------
if __name__ == "__main__":
    extractor = DocumentMetadataExtractor(
        folder_path=r"C:\Users\Cymonic\Desktop\Cymonic\HR_BOT\WorkMate",          # folder containing FAQ documents
        output_file="metadata.json"     # output JSON file
    )
    extractor.run()
# Out:
# Metadata extracted for 4 files successfully.
